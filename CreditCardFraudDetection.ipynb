# %% [markdown]
# ```
# # This is formatted as code
# ```
# ## Importing The **Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Reading The Data Set

# %%
ccdata=pd.read_csv('/content/creditcard.csv')
# Out:
# <ipython-input-2-4225324680d8>:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   ccdata=pd.read_csv('/content/creditcard.csv')

# %%
ccdata.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ccdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33760 entries, 0 to 33759
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    33760 non-null  int64
#  1   V1      33760 non-null  float64
#  2   V2      33760 non-null  float64
#  3   V3      33760 non-null  float64
#  4   V4      33760 non-null  float64
#  5   V5      33760 non-null  float64
#  6   V6      33760 non-null  float64
#  7   V7      33760 non-null  float64
#  8   V8      33760 non-null  float64
#  9   V9      33760 non-null  float64
#  10  V10     33760 non-null  float64
#  11  V11     33760 non-null  float64
#  12  V12     33760 non-null  float64
#  13  V13     33760 non-null  float64
#  14  V14     33760 non-null  float64
#  15  V15     33760 non-null  float64
#  16  V16     33760 non-null  float64
#  17  V17     33760 non-null  float64
#  18  V18     33760 non-null  float64
#  19  V19     33760 non-null  float64
# ...

# %%
#missing value in the data_set
ccdata.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# # Distribution of Normal and Fraud Transaction

# %%
ccdata['Class'].value_counts()
# Out:
# 0.0    33656
# 1.0      103
# Name: Class, dtype: int64

# %%
#Seprate the data
normal = ccdata[ccdata.Class==0]
fraud = ccdata[ccdata.Class==1]

# %%
normal.shape
# Out:
# (33656, 31)

# %%
fraud.shape
# Out:
# (103, 31)

# %% [markdown]
# # Building New Normal Data Set containing similar distribution of normal and fraud detection

# %%
normal_sample = normal.sample(n=492)

# %%
#Concatenating the two dataset
new_dataset = pd.concat([normal_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 21977  31967 -1.176751  1.436313 -0.237459  1.319527 -1.514517  0.301280
# 6051    6847  0.247668 -1.779577  0.898157  0.845155 -1.804269 -0.434420
# 6300    7442 -4.600894  0.673134  1.328519  0.816556  0.519533  2.415755
# 20687  31208  1.297454 -0.529645  0.053969 -0.812724 -0.628899 -0.521468
# 8814   12031 -0.689934  0.388272  1.923482 -0.610600  0.112817 -0.586144
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 21977  1.300045  0.571179 -1.185019  ...  0.225937  0.728988  0.186755
# 6051  -0.125657 -0.186263  2.300514  ...  0.050361 -0.533227 -0.320473
# 6300   1.386262 -1.601209  4.303526  ... -0.374100  1.422811 -0.698892
# 20687 -0.354849  0.000649 -1.203056  ... -0.121003  -0.58747  0.136201
# 8814   0.288550  0.003101  1.551985  ... -0.097018  0.106893 -0.086591
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.shape
# Out:
# (595, 31)

# %% [markdown]
# # Splitting the new Data_set into X and Y

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %%
X
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 21977  31967 -1.176751  1.436313 -0.237459  1.319527 -1.514517  0.301280
# 6051    6847  0.247668 -1.779577  0.898157  0.845155 -1.804269 -0.434420
# 6300    7442 -4.600894  0.673134  1.328519  0.816556  0.519533  2.415755
# 20687  31208  1.297454 -0.529645  0.053969 -0.812724 -0.628899 -0.521468
# 8814   12031 -0.689934  0.388272  1.923482 -0.610600  0.112817 -0.586144
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V20       V21  \
# ...

# %%
Y
# Out:
# 21977    0.0
# 6051     0.0
# 6300     0.0
# 20687    0.0
# 8814     0.0
#         ...
# 30442    1.0
# 30473    1.0
# 30496    1.0
# 31002    1.0
# 33276    1.0
# Name: Class, Length: 595, dtype: float64

# %% [markdown]
# # Splitting the Dataset into Training Data and Testing Data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=42)

# %%
print(X_train,X_test,Y_train,Y_test)
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 32630  36888   1.227689  -0.315448   0.963118  0.294709  -0.893720 -0.054095
# 25072  33509   0.870980  -1.485273   1.037208 -0.368346  -1.152210  1.548625
# 16094  27511   1.408483  -0.382352   0.101670 -0.526548  -0.754507 -1.064001
# 5041    4652  -1.289699  -0.959548   0.951773 -3.437411  -0.865271 -0.901859
# 10144  15517   0.822881  -0.340575   1.394033  2.092199  -0.807360  0.526166
# ...      ...        ...        ...        ...       ...        ...       ...
# 19738  30514   1.489685  -1.142862   0.799434 -1.304794  -1.913395 -0.820805
# 5849    6352  -2.820557   2.866556  -1.695472 -1.273598   1.641280  3.093000
# 9756   14484  -0.343707   0.710785   1.410740 -0.744142   0.455002  0.796509
# 15451  26833 -20.532751  12.373989 -23.009003  6.144821 -15.587296 -4.384491
# 21874  31906  -0.345979   1.094568   1.282208  0.068241  -0.016965 -0.989567
#
# ...

# %% [markdown]
# # Model Training-Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model Evaluation- Accuracy Score

# %%
y_predict = model.predict(X_test)

# %%
acc=accuracy_score(Y_test,y_predict)

# %%
acc
# Out:
# 0.9747899159663865
